# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('internal.csv')
y = pd.read_csv('output.csv')

# %%
y[y['Survived']==1].sum()
# Out:
# PassengerId    150446
# Survived          137
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(), annot=True)

# %%
data.hist(figsize=(16,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe71705c400>,
# ...
#       dtype=object)

# %%
data.head()
# Out:
#    Survived      Name  Sex       Age     SibSp     Parch    Ticket  1st  2nd  \
# 0         0 -0.072049    0 -0.153061  0.063795 -0.067918  0.199940    0    0
# 1         1  0.436720    1  0.165025  0.063795 -0.067918  0.111045    1    0
# 2         1 -0.090219    1 -0.073540 -0.069949 -0.067918  0.822209    0    0
# 3         1  0.309528    1  0.105383  0.063795 -0.067918 -0.066746    1    0
# 4         0 -0.053879    0  0.105383 -0.069949 -0.067918 -0.066746    0    0
#
#    3rd
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
