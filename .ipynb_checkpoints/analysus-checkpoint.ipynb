# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('titanic/train.csv')

# %%
len(data)
# Out:
# 891

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.isnull())

# %%
data = data.drop('Cabin', axis=1)

# %%
data = data.replace({'male':0, 'female':1})

# %%
for i in range(0, len(data)):
    data.loc[i, 'Name'] = len(data.loc[i, 'Name'])

# %%
for i in range(0, len(data)):
    data.loc[i, 'Ticket'] = len(data.loc[i, 'Ticket'])

# %%
data = data.replace({'S':0, 'Q':1, 'C':2})

# %%
co = data.corr()
plt.subplots(figsize=(10,10))
sns.heatmap(co, annot=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3    23    0  22.0      1      0       9
# 1              2         1       1    51    1  38.0      1      0       8
# 2              3         1       3    22    1  26.0      0      0      16
# 3              4         1       1    44    1  35.0      1      0       6
# 4              5         0       3    24    0  35.0      0      0       6
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2    21    0  27.0      0      0       6
# 887          888         1       1    28    1  19.0      0      0       6
# 888          889         0       3    40    1   NaN      1      2      10
# 889          890         1       1    21    0  26.0      0      0       6
# 890          891         0       3    19    0  32.0      0      0       6
#
#         Fare  Embarked
# 0     7.2500       0.0
# 1    71.2833       2.0
# 2     7.9250       0.0
# 3    53.1000       0.0
# 4     8.0500       0.0
# ..       ...       ...
# 886  13.0000       0.0
# 887  30.0000       0.0
# 888  23.4500       0.0
# 889  30.0000       2.0
# 890   7.7500       1.0
#
# [891 rows x 11 columns]

# %%
data.hist(figsize=(16,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf805f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf8175c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf7c5b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf7800f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf7b06a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf75fc50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf71f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf6ce828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf6ce860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf640390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf66f940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7dcf623ef0>]],
#       dtype=object)

# %%
data = data.drop(['Embarked'], axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3    23    0  22.0      1      0       9
# 1              2         1       1    51    1  38.0      1      0       8
# 2              3         1       3    22    1  26.0      0      0      16
# 3              4         1       1    44    1  35.0      1      0       6
# 4              5         0       3    24    0  35.0      0      0       6
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2    21    0  27.0      0      0       6
# 887          888         1       1    28    1  19.0      0      0       6
# 888          889         0       3    40    1   NaN      1      2      10
# 889          890         1       1    21    0  26.0      0      0       6
# 890          891         0       3    19    0  32.0      0      0       6
#
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 10 columns]

# %%
data[['Survived', 'Pclass', 'Age']].plot(kind='scatter', x='Pclass', y='Age', c='Survived', colormap='winter', figsize=(14,12))
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
data[data['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# 5              6         0       3    16    0  NaN      0      0       6
# 17            18         1       2    28    0  NaN      0      0       6
# 19            20         1       3    23    1  NaN      0      0       4
# 26            27         0       3    23    0  NaN      0      0       4
# 28            29         1       3    29    1  NaN      0      0       6
# ..           ...       ...     ...   ...  ...  ...    ...    ...     ...
# 859          860         0       3    16    0  NaN      0      0       4
# 863          864         0       3    33    1  NaN      8      2       8
# 868          869         0       3    27    0  NaN      0      0       6
# 878          879         0       3    18    0  NaN      0      0       6
# 888          889         0       3    40    1  NaN      1      2      10
#
#         Fare
# 5     8.4583
# 17   13.0000
# 19    7.2250
# 26    7.2250
# 28    7.8792
# ..       ...
# 859   7.2292
# 863  69.5500
# 868   9.5000
# 878   7.8958
# 888  23.4500
#
# [177 rows x 10 columns]

# %%
data_tr = data.drop('PassengerId', axis=1)

# %%
data_reduce = data_tr.dropna()

# %%
data_tr.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# dtype: int64

# %%
data_reduce.mean()
# Out:
# Survived     0.406162
# Pclass       2.236695
# Name        27.693277
# Sex          0.365546
# Age         29.699118
# SibSp        0.512605
# Parch        0.431373
# Ticket       6.841737
# Fare        34.694514
# dtype: float64

# %%
data_tr.mean()
# Out:
# Survived     0.383838
# Pclass       2.308642
# Name        26.965208
# Sex          0.352413
# Age         29.699118
# SibSp        0.523008
# Parch        0.381594
# Ticket       6.750842
# Fare        32.204208
# dtype: float64

# %%
MEAN_VALUES = data_tr.mean()

# %%
avgfull = np.array(data_tr.mean())
(np.array(data_reduce.mean()) - avgfull) / avgfull * 100.0
# Out:
# array([ 5.81601061, -3.11643374,  2.70003365,  3.7266499 ,  0.        ,
#        -1.98903596, 13.0449827 ,  1.34642386,  7.73285913])

# %%
data.to_csv('dataset/train_id.csv')

# %%
data_tr = data_tr.fillna(data_tr['Age'].mean())

# %%
data_tr.to_csv('dataset/train.csv')

# %%
data_reduce.to_csv('dataset/train_red.csv')

# %% [markdown]
# # Gender impact

# %%
data_g = data.loc[np.where(data['Sex']!=data['Survived'])]
data_g = data_g.drop('PassengerId', axis=1)

# %%
plt.figure(figsize=(18,8))
sns.heatmap(data_g.corr(), annot=True)

# %%
data_g.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Name         0
# Sex          0
# Age         33
# SibSp        0
# Parch        0
# Ticket       0
# Fare         0
# dtype: int64

# %%
data_g = data_g.fillna(MEAN_VALUES['Age'])

# %%
len(data_g)
# Out:
# 190

# %%
data_related = data_tr.loc[np.where(data_tr['Survived']==data_tr['Sex'])]
len(data_related)
# Out:
# 701

# %%
data_g = data_g.append( data_related.sample(n=190) )
data_g
# Out:
#      Survived  Pclass  Name  Sex        Age  SibSp  Parch  Ticket     Fare
# 14          0       3    36    1  14.000000      0      0       6   7.8542
# 17          1       2    28    0  29.699118      0      0       6  13.0000
# 18          0       3    55    1  31.000000      1      0       6  18.0000
# 21          1       2    21    0  34.000000      0      0       6  13.0000
# 23          1       1    28    0  28.000000      0      0       6  35.5000
# ..        ...     ...   ...  ...        ...    ...    ...     ...      ...
# 782         0       1    22    0  29.000000      0      0       6  30.0000
# 262         0       1    17    0  52.000000      1      1       6  79.6500
# 330         1       3    18    1  29.699118      2      0       6  23.2500
# 556         1       1    65    1  48.000000      1      0       5  39.6000
# 238         0       2    31    0  19.000000      0      0       5  10.5000
#
# [380 rows x 9 columns]

# %%
data_g.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# dtype: int64

# %%
data_g.to_csv('dataset/train_g.csv')

# %%
MEAN_VALUES
# Out:
# Survived     0.383838
# Pclass       2.308642
# Name        26.965208
# Sex          0.352413
# Age         29.699118
# SibSp        0.523008
# Parch        0.381594
# Ticket       6.750842
# Fare        32.204208
# dtype: float64

# %% [markdown]
# # Test dataset

# %%
data = pd.read_csv('titanic/test.csv')

# %%
data = data.drop(['Embarked', 'Cabin'], axis=1)

# %%
data = data.replace({'male':0, 'female':1})
for i in range(0, len(data)):
    data.loc[i, 'Name'] = len(data.loc[i, 'Name'])
    data.loc[i, 'Ticket'] = len(data.loc[i, 'Ticket'])

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.isnull())

# %%
data_tr = data.drop('PassengerId', axis=1)

# %%
data_tr = data_tr.fillna(MEAN_VALUES['Age'])

# %%
data_tr.to_csv('dataset/test.csv')
data.to_csv('dataset/test_id.csv')

# %% [markdown]
# # Output

# %%
data = pd.read_csv('titanic/test.csv')

# %%
data = data.drop(['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1)

# %%
data['Survived'] = [0] * len(data)

# %%
data
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         0
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
data.to_csv('output.csv', index=False)

# %%
pd.DataFrame(MEAN_VALUES).transpose().to_csv('meta_mean.csv', index=False)
